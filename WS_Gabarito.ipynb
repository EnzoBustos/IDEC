# %% [markdown]
# <img src="https://drive.google.com/uc?id=13F0LS04AY8Onem1Nx2yvu4SDF_TsTSwI">
#
# <h1><li> Visualização de Dados com Python </li></h1>
#
# ---
# <br>
#
# Autor: Enzo Bustos da Silva
#
# Sobre mim:
#
# > Estou no 2° ano de engenharia elétrica - ênfase em computação
#
# > Diretor de Patrimônio pelo [CAM](https://www.facebook.com/cam.poli.usp/)
#
# > Membro de área de P&D com foco em CV pelo [Grupo Turing](https://www.facebook.com/grupoturing.usp/)
#
# <br>
#
# ---
#
# <br>
#
# Na aula de hoje falaremos um pouco sobre o tópico de visualização de dados usando algumas bibliotecas de Python, passando por um pouquinho de `pandas` e principalmente `seaborn`.

# %% [markdown]
# <h1><li> Seaborn </li></h1>
#
# ---
#
# <img src="https://drive.google.com/uc?id=1PQGyQhu_jxhil5jrncCyDWU2WfzQha75" width=500>
#
# *   É uma biblioteca de Python para visualização de dados
# *   Cria com poucas linhas de códigos os gráficos mais comuns
# *   Muito importante para interpretar seus dados e comunicar resultados
# *   Biblioteca construida em cima da `matplotlib`
#
# Grande interação com `pandas` que veremos mais para frente

# %%
# Importa as bibliotecas com as abreviações usuais
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Podemos como exemplo tentar plottar um gráfico de relação entre alguns dados de altura e peso e, ver se existe alguma relação entre eles.
#
# Veja como é simples, fácil e rápido fazer um gráfico com essas duas listas, note que nesse exemplo estamos usando um `scatterplot` que consiste basicamente em um gráfico de pontos.

# %%
altura = [157, 163, 175, 190, 168, 173, 165, 180, 193, 185]
peso   = [ 54,  62,  67,  79,  62,  75,  70,  78,  91,  85]

sns.scatterplot(x=altura, y=peso)

# %% [markdown]
# Outro problema que talvez possamos ter é quando estamos trabalhando com variáveis categóricas, nesse caso é mais interessante usarmos um `countplot` que vai contar as aparições dessas variáveis.

# %%
sexo = ["Mulher", "Mulher", "Mulher", "Mulher", "Mulher", 
        "Mulher", "Homem", "Homem", "Homem", "Homem"]

sns.countplot(x=sexo)

# %% [markdown]
# Certo, tudo isso está bem simples então vamos deixar as coisas um pouquinho mais emocionantes usando `pandas`.

# %% [markdown]
# <h1><li> Pandas </li></h1>
#
# ---
#
# <img src='https://drive.google.com/uc?id=1AQeJeLnt08d8QGsOHx6RuVN4VLy1Ky5v' width=500>
#
# *   Acrônimo de "Python and Data Analysis"
# *   É uma biblioteca de Python para análise de dados
# *   Facilmente lê arquivos de dados em csv, txt e muitos outros modos
# *   Manipula facilmente tabelas de dados, chamadas de `DataFrame`
#
# O `seaborn` tem uma conexão muito forte com o `pandas` sendo extremamente útil e versátil para conseguirmos visualizar grandes quantidades de dados que podemos estar trabalhando com o `pandas`. No nosso exemplo, estarei usando o `tips dataset` (adaptado para esse Workshop) que consiste de algumas informações sobre gorjetas nos Estados Unidos.
#
# <img src='https://drive.google.com/uc?id=11SU6iN2hiGjJSeS8Wp5CExcY61NRYNvE' width=500>
#
# Algumas funções iniciais que são úteis para você ter um panorâma dos seus dados são:
#
# *   df.head() ➝ mostras as primeiras linhas da sua tabela
# *   df.info() ➝ maneira rápida de ver os tipos de dados, número de colunas e quantas observações existem
# *   df.describe() ➝ passa alguns dados estatísticos de variáveis numéricas ou um panorâma das variáveis categóricas
#
# df é o objeto que contém o seu `DataFrame` é só um nome usual que você pode encontrar tanto em exemplos quanto na própria documentação.

# %%
# importando o pacote pelo seu nome usual
import pandas as pd

# código para podermos ler um arquivo csv e guardamos o objeto DataFrame dentro da variável gorjeta
gorjeta = pd.read_csv('./gorjeta.csv')
gorjeta.head() # teste o info() e o describe() também

'''
Se quiser você também pode importar esse conjunto de dados usando
gorjeta = sns.load_dataset('tips')
que também vai devolver um DataFrame
'''
# Out:
# "\nSe quiser você também pode importar esse conjunto de dados usando\ngorjeta = sns.load_dataset('tips')\nque também vai devolver um DataFrame\n"

# %% [markdown]
# Vamos então aplicar alguns dos plots que vimos anteriormente com o `pandas`, daqui para a frente não usarei mais listas de Python puro, apenas `DataFrame` vocês vão ver que é bem simples e você se refere a ele como se fosse um dicionário em Python, mas o `seaborn` oferece um jeito muito fácil de fazer, nos seus eixos você só precisa especificar a `string` que nomeia uma coluna e passar o parâmetro `data` com a sua tabela de dados
#
# Vamos plottar agora um `scatterplot`, que são gráficos de pontos geralmente usados quando cada ponto é uma observação diferente:

# %%
sns.scatterplot(x='conta', y='gorjeta', data=gorjeta)

# %% [markdown]
# Tente agora fazer um `countplot` da coluna 'sexo' para vermos as distribuições de homens e mulheres dentro do nosso conjunto de dados:

# %%
# ===== COMPLETE =====

sns.countplot(x='sexo', data=gorjeta)

# %% [markdown]
# Legal, poder visualizar a relação de 2 variáveis já é bem útil e pode quebrar um galho com vários problemas que podemos ter em engenharia como para plottar gráficos de funções por exemplo, mas e se quisermos ver como uma terceira variável influencia nossas tendências ?
#
# Claro que o `seaborn` tem um parâmetro para isso que é o `hue`, esse parâmetro vai colorir seus dados conforme as observações de uma outra variável, observe:

# %%
sns.scatterplot(x='conta', y='gorjeta', data=gorjeta, hue='fumante')

# %% [markdown]
# Não preciso nem falar que o `hue` é extremamente personalizável, o parâmetro `hue_order` especifíca a ordem que você quer que a legenda aparece e o parâmetro `palette` pode receber um dicionário que mapeia o rótulo a uma determinada cor específica de sua preferência (Confira nomes das cores [aqui](https://python-graph-gallery.com/100-calling-a-color-with-seaborn/), você também pode usar o código hexadecimal das cores para ter um poder de personalização ainda melhor

# %%
cores = {'Sim' : 'black',
         'Não' : 'gold',}

sns.scatterplot(x='conta', y='gorjeta', data=gorjeta, hue='fumante', palette=cores, hue_order=['Sim', 'Não'])

# %% [markdown]
# `hue` é um parâmetro bem importante que está presente em praticamente todos os gráficos dentro de `seaborn`, tente ver a quantidade de fumantes presentes entre os homens e entre as mulheres dos nossos dados, para isso faça um `countplot` que tenha o parâmetro `hue` e depois tente personalizar ao seu gosto:

# %%
# ===== COMPLETE =====

sns.countplot(x='sexo', data=gorjeta, hue='fumante')

# %% [markdown]
# <h1><li> Variáveis quantitativas </li></h1>
#
# ---
#
# <img src='https://drive.google.com/uc?id=1N7dtGxBsR66jT3wUck6ScUcACmwqdfNm' width=500>

# %% [markdown]
# Bom, a principal funcionalidade dos gráficos é relacionar `features`, ou seja, comparar atributos dos nossos dados para ver como eles se relacionam entre si e nós já fizemos isso tentando ver se existe uma relação entre peso e altura ou ainda no exemplo entre gorjetas e conta.
#
# Esses gráficos são chamados de gráficos relacionais, e também estão implementados em `seaborn` como `relplot`, a vantagem de se utilizar um `relplot` é que é muito fácil criar `subplots`, que são múltiplos gráficos. Nele podemos especificar o `kind` que é o tipo de gráfico que queremos, como *line*, *scatter*, entre outros.

# %%
sns.relplot(x='conta', y='gorjeta', data=gorjeta, kind='scatter', col='fumante')

# %% [markdown]
# Tente agora você, usar o parâmetro `col` do `relplot` para ver se a gorjeta tem alguma relação com o dia em que foi feita a compra:

# %%
# ===== COMPLETE =====

sns.relplot(x='conta', y='gorjeta', data=gorjeta, col='dia', col_wrap=2)

# %% [markdown]
# Vamos ver agora algumas customizações que você pode fazer no seu `scatterplot`, para deixar ele visualmente mais atrativo e informativo ao usuário, uma primeira modificação é aumentar o tamanho do ponto, para nosso exemplo vamos fazer esse tamanho ser relacionado ao número de pessoas no grupo.

# %%
sns.relplot(x='conta', y='gorjeta', data=gorjeta, kind='scatter', size='tamanho', hue='tamanho')

# %% [markdown]
# Outra customização interessante é com o parâmetro `style` que usa um ponto com uma forma diferente para diferenciar os dados.

# %%
sns.relplot(x='conta', y='gorjeta', data=gorjeta, kind='scatter', style='fumante', hue='fumante')

# %% [markdown]
# Por último, pode ser interessante mudarmos a transparência do nosso ponto usando o parâmetro `alpha`, isso pode ser útil quando quisermos usar um `scatterplot` e tivermos muitos pontos um por cima do outro, podendo assim diverenciar em que região há mais observações.

# %%
sns.relplot(x='conta', y='gorjeta', data=gorjeta, kind='scatter', alpha=0.4)

# %% [markdown]
# Vamos agora plottar `lineplots`, que são os famosos gráficos de linhas. Devemos sempre pensar em `lineplots` como opção válida quando temos muitos dados para se observar, ocorrendo muito `overlap` de pontos ou quando cada observação se refere ao mesmo assunto, geralmente um acompanhamento ao longo do tempo para dados relacionados.
#
# Para isso vamos usar um novo dataset (dessa vez em inglês mesmo) sobre o preço de abacates, esse dataset pode ser encontrado [aqui](https://www.kaggle.com/neuromusic/avocado-prices)
#
# <img src='https://drive.google.com/uc?id=1rpggfiwaYgWQt2_BaqKL1Tkle8IZ2xYn' width=500>

# %%
avocado = pd.read_csv('avocado.csv')
avocado['Date'] = pd.to_datetime(avocado['Date']) #Converte em um valor legível de data
avocado.head()
# Out:
#         Date  AveragePrice  Total Volume  ...          type  year  region
# 0 2015-12-27          1.33      64236.62  ...  conventional  2015  Albany
# 1 2015-12-20          1.35      54876.98  ...  conventional  2015  Albany
# 2 2015-12-13          0.93     118220.22  ...  conventional  2015  Albany
# 3 2015-12-06          1.08      78992.15  ...  conventional  2015  Albany
# 4 2015-11-29          1.28      51039.60  ...  conventional  2015  Albany
#
# [5 rows x 13 columns]

# %% [markdown]
# Certo, vamos tentar ver a relação do preço médio dos nossos abacates com a data que eles foram vendidos para ver se conseguimos extrair alguma coisa

# %%
sns.relplot(x=avocado['Date'], y=avocado['AveragePrice'], kind='line')
plt.xticks(rotation=45) #use isso para variar a angulação da legenda do eixo x
# Out:
# (array([735599., 735719., 735842., 735964., 736085., 736208., 736330.,
#         736450., 736573., 736695., 736815.]),
#  <a list of 11 Text major ticklabel objects>)

# %% [markdown]
# Os `lineplots` também são passíveis de muita personalização, vamos agora aplicar o parâmetro `style` para personalizar as linhas e `hue` para personalizar as cores, baseados na região onde foram coletados esses preços:

# %%
'''
sns.relplot(x='Date', y='AveragePrice', data=avocado,
            kind='line', style='region', hue='region')
plt.xticks(rotation=45)
'''
# Out:
# "\nsns.relplot(x='Date', y='AveragePrice', data=avocado,\n            kind='line', style='region', hue='region')\nplt.xticks(rotation=45)\n"

# %% [markdown]
# <img src='https://drive.google.com/uc?id=15dDM2Wq2Lsn7aLLh6MUaR0chSdsigvGA'>

# %% [markdown]
# Esse gráfico ficou péssimo! Está muito confuso, pois tem muitas variáveis no meu `plot`, então o que fazemos quando nos encontramos com problemas como esse ?
#
# Também é parte do trabalho do ciencista de dados entender um problema, então com um pouco de pesquisa podemos chegar a algumas regiões que são mais importantes para o nosso estudo.
#
# Vamos selecionas só as linhas que contém essas regiões e plottar só com elas para ver o que temos.
#
# (observe que esse é só um exemplo de abordagem, você também poderia tentar fazer um `cluster` de regiões baseado na proximidade entre elas por exemplo)

# %%
regions = ["California", "West", "SouthCentral", "GreatLakes",
           "Midsouth", "Southeast", "Northeast", "Plains"]

avocado = avocado.loc[avocado['region'].isin(regions)]

sns.relplot(x='Date', y='AveragePrice', data=avocado,
            kind='line', style='region', hue='region')
plt.xticks(rotation=45)
# Out:
# (array([735599., 735719., 735842., 735964., 736085., 736208., 736330.,
#         736450., 736573., 736695., 736815.]),
#  <a list of 11 Text major ticklabel objects>)

# %% [markdown]
# Ficou um pouco melhor mas ainda podemos melhorar, tirando nosso intervalo de confiança (que é essa sombra que está atrás de cada linha) utilizando o parâmetro `ci`, podemos também brincar com as linhas que temos usando os parâmetro `dashes=False`, para usar uma linha sólida em todas e `markers=True`, para ativar marcações em cada ponto e essa marcação é baseada no subgrupo em `style`.
#
# Nota: O intervalo de confiança é mostrado quando temos mais de uma observação por um determinado valor de x e, por padrão ele nos dá 95% para a média (que é a linha em display), podemos modificar usando o parâmetro `ci` e passando diferentes valores como `sd` para o IC de desvio padrão ou ainda com `None` para ele não ser mostrado.

# %%
sns.relplot(x='Date', y='AveragePrice', data=avocado,
            kind='line', style='region', hue='region',
            ci=None, dashes=False) #teste com os markers também

plt.xticks(rotation=45)
# Out:
# (array([735599., 735719., 735842., 735964., 736085., 736208., 736330.,
#         736450., 736573., 736695., 736815.]),
#  <a list of 11 Text major ticklabel objects>)

# %% [markdown]
# Agora é sua vez, tente aplicar esses conceitos da nossa primeira parte para ver se entendeu!
#
# a) Primeiro importe o dataset, dos preços de abacate novamente, nota que o arquivo se chama `avocado.csv` e use a função de `pandas` para fazer isso.
#
# b) Agora tente comparar o preço médio do abacate em relação as datas igual estávamos fazendo só que dessa vez, ao invés de separar por região use como parâmetro o tipo do abacate, para ver se ele é to tipo convencional ou orgânico.
#
# c) Personalize o gráfico obtido usando os parâmetros `palette` e `hue_order`. Ainda pode tentar usar `col` para ver se consegue uma visualização mais expressiva.

# %%
# A) ========================================

avocado = pd.read_csv('avocado.csv')
avocado['Date'] = pd.to_datetime(avocado['Date'])

# B) ========================================

sns.relplot(x='Date', y='AveragePrice', data=avocado,
            style='type', hue='type', kind='line', ci=None) #Tente personalizar com dashes, markers e ci

plt.xticks(rotation=45) #Varie se quiser

# C) ========================================

colors = {
          'conventional' : 'gold',
          'organic' : 'aquamarine',
          }

sns.relplot(x='Date', y='AveragePrice', data=avocado,
            style='type', hue='type', kind='line',
            palette=colors, ci=None, dashes=False,
            hue_order=['organic', 'conventional'],
            ) #Tente usar além dos dashes e markers, hue_order e col/row

plt.xticks(rotation=45)
# Out:
# (array([735599., 735719., 735842., 735964., 736085., 736208., 736330.,
#         736450., 736573., 736695., 736815.]),
#  <a list of 11 Text major ticklabel objects>)

# %% [markdown]
# <h1><li> Variáveis Categóricas e Quantitativas </li></h1>
#
# ---
#
# <img src='https://drive.google.com/uc?id=1BicXm6jbUJtK4fR2tyFoI3Xu4seUiLxk' width=300>

# %% [markdown]
# Certo, agora vamos focar em algumas visualizações para variáveis categóricas, variáveis que representam valores qualitativos e não são são numéricas, como por exemplo se estamos com uma análise de escolaridade valores como homem e mulher são categóricos, da mesma forma que um nível de escolaridade em fundamental, médio e superior também é categórico, embora esse último possa ser ordenado.
#
# Nessa parte vamos passar por cima de `countplots` e `barplots`, eles envolvem geralmente a comparação entre os grupos de alguma variável categórica, para esse módulo usaremos o `catplot()` uma função que funciona mais ou menos como a `relplot()` para dados categóricos, novamente sendo fácil criar `subplots` com os parâmetros `row` e `col`.

# %% [markdown]
# Vamos olhar isso mais de perto com o dataset do Titanic, que consta de várias observações sobre os passageiros, como sexo, idade, qual a classe da passagem, onde embarcou entre outros fatores e nossa variável alvo é se eles sobreviveram ou não ao incidente.
#
# <img src='https://drive.google.com/uc?id=1N9G-ftBZsYpC3IiyrPHsHSLFzBvJC-Zi' width=500>

# %% [markdown]
# Primeiro o de sempre, vamos abrir nosso dataset com `pandas` e dar uma olhada geral nos nossos dados, os dados podem ser encontrados [aqui](https://www.kaggle.com/c/titanic/data) junto com o mapa do que significa cada uma das features e [aqui](https://medium.com/@alegeorgelustosa/an%C3%A1lise-explorat%C3%B3ria-e-preditiva-do-dataset-titanic-em-python-fbd5e5bb7328) você pode conferir uma análise preditiva desses dados e o mapa de significados em português.

# %%
titanic = pd.read_csv('titanic.csv')
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Survived     1309 non-null   int64
#  2   Pclass       1309 non-null   int64
#  3   Name         1309 non-null   object
#  4   Sex          1309 non-null   object
#  5   Age          1046 non-null   float64
#  6   SibSp        1309 non-null   int64
#  7   Parch        1309 non-null   int64
#  8   Ticket       1309 non-null   object
#  9   Fare         1308 non-null   float64
#  10  Cabin        295 non-null    object
#  11  Embarked     1307 non-null   object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 122.8+ KB

# %% [markdown]
# Primeiro, antes de plottarmos nosso `catplot` vamos aplicar um pouquinho de `pandas` para mudarmos os rótulos nos nossos portos, pois eles estão só com as iniciais e isso não é muito legal (ainda mais para a gente que provavelmente não conhece esses portos).
#
# Uma coisa interessante é que você pode mudar a ordem em que as categorias aparecem no seu gráfico com base no parâmetro `order`, que recebe uma lista da ordem que você quer e ainda funcionam outros parâmetro como o `palette` que já tinhamos visto.

# %%
#Mapeamento das mudanças
portos = {
    'C': 'Cherbourg',
    'Q': 'Queenstown',
    'S': 'Southampton',
}

#Código para mudarmos nossa coluna com base no dicionário
titanic['Embarked'].replace(portos, inplace=True)

# %%
ordem = ['Queenstown', 'Cherbourg', 'Southampton']

cores = {
    'Queenstown': 'black', 
    'Cherbourg': 'gold', 
    'Southampton': 'aquamarine',
}

#Tente usar os parâmetros order e palette para personalizar o seu gráfico
sns.catplot(x='Embarked', data=titanic,
            kind='count')

# %% [markdown]
# Os `barplot` são um pouco diferentes, eles mostram a média de uma variável quantitativa por categoria. Por exemplo, podemos ver a média dos preços das passagens em 'Fare' baseado no porto em que a pessoa embarcou, pois parece que faz sentido essa relação.
#
# Como vimos também antes, o `seaborn` já automaticamente nos dá um intervalo de confiança de 95% para nossa média e isso pode ser ajustado com o parâmetro `ci`.

# %%
sns.catplot(x='Embarked', y='Fare', data=titanic, kind='bar')

# %% [markdown]
# É possível rotacionar seu gráfico trocando os parâmetros x e y, tendo assim um gráfico na horizontal, porém isso não é muito recomendado.

# %% [markdown]
# Um gráfico extremamente versátil e útil é o `boxplot` que também pode ser feito com facilidade no `seaborn` e é bem útil por ser uma ferramente estatística forte também na hora de visualizar nossos dados, da mesma forma que o `barplot` ele plotta a relação de uma variável numérica baseado em uma categoria escolhida.
#
# A melhor parte do `boxplot` é que ele nos dá muitas informações, como o quanto seus dados estão espalhados, os quartis e até os `outliers` e facilita muito a comparação entre os grupos.
#
# Nota: você pode omitir os `outliers` com o parâmetro `sym=''` ou ainda alterar o display dele, por padrão os `outliers` são calculados por: $1.5*IQR$
#
# Em que o IQR é a distância interquartis, mas isso pode ser alterado usando o parâmetro `whis` que pode receber um número que multiplicará o IQR ou ainda uma lista que irá considerar os percentis desejados (esse parâmetro controla mais especificamente as linhas cinzas acima e abaixo do `boxplot`)

# %%
#Veja também a relação entre Survived e Fare
#Utilize o parâmetro sym e whis também
g = sns.catplot(x='Embarked', y='Fare', data=titanic,
                kind='box', sym='')

# %% [markdown]
# Por último vale mostrar os `pointplots` que são gráficos muito parecidos com os `barplots` só que ao invés de barras são representados apenas pontos e são muito úteis para comparar variáveis categóricas que apresentam alguma ordenação inerente

# %%
#Vamos agora categorizar nossas idades

divisões = [0, 12, 25, 37, 51, 80]
nomes = ['Criança', 'Jovem', 'Adulto', 'Meia-Idade', 'Idoso']
titanic['Age'] = pd.cut(titanic['Age'], divisões, labels=nomes)

# %%
#Agora vamos fazer uma comparação do barplot com o pointplot

sns.catplot(x='Age', y='Fare', hue='Sex',data=titanic, kind='bar')
sns.catplot(x='Age', y='Fare', hue='Sex',data=titanic, kind='point')

# %% [markdown]
# Mesmo eles tendo uma ideia muito parecida, o `pointplot` torna muito mais fácil visualizar de viasualizar a inclinações da reta e quando os dados estão um sobre o outro (para de uma ideia do quanto estão acima).
#
# É ainda possível retirar as linhas que ligam os pontos com o parâmetro `join=False` e também pode colocar linhas no final dos intervalos de confiança com o parâmetro `capsize`.

# %% [markdown]
# <h1><li> Customizando seus plots </li></h1>
#
# ---
#
# <img src='https://drive.google.com/uc?id=1b5FK0muuELXj0NDkvjBVkzD5T_59T874' width=500>

# %% [markdown]
# Gráficos de `seaborn` já são bem agradáveis de se olhar, mas por qual motivo então eu deveria personalizar eles ainda mais ?
#
# Bom, isso pode ir desde preferência pessoal até melhorar a legibilidade ou até guiar até sua interpretação.
#
# Existem alguns modelos de estilo já predefinidos que podem ser modificados utilizando o comando `sns.set_style()`, que pode receber algumas opções como: 'white', 'dark', 'whitegrid', 'darkgrid', 'ticks'. Por padrão o `seaborn` utiliza o 'white'.

# %%
#Mude os estilos aqui
sns.set_style('darkgrid')
sns.catplot(x='Age', y='Fare', hue='Sex',data=titanic, kind='point')

# %% [markdown]
# Temos também o comando `sns.set_palette()` que define as cores dos principais elementos, você pode usar uma paleta de cores pré-definida ou ainda criar o seu próprio estilo de cores, através de uma lista de nomes de cores ou de códigos hexadecimais
#
# Você pode conferir algumas das paletas existentes [aqui](https://seaborn.pydata.org/tutorial/color_palettes.html)
#
# Os principais estilos de paletas são:
#
# *   Divergentes: quando os dois extremos tem grande impacto
# *   Sequencial: para dados em que um dos extremos importa

# %%
#Abra a documentação e teste algumas paletas
sns.set_palette('mako')
sns.catplot(x='Age', y='Fare',data=titanic, kind='bar', ci=None)

# %% [markdown]
# Também podemos mudar a escala do nosso plot com a função `sns.set_context()` que estaria especificando o contexto de apresentação desse gráfico, do menor para o maior podemos colocar os parâmetros: 'paper', 'notebook', 'talk', 'poster'.
#
# Por padrão o `seaborn` utiliza 'paper'

# %%
sns.set_context('paper')
sns.relplot(x='conta', y='gorjeta', data=gorjeta, kind='scatter', size='tamanho', hue='tamanho')

# %% [markdown]
# Uma das informações mais cruciais na hora de passar a informação sobre o seu gráfico é definir um bom título e também subtítulos para cada um dos eixos, de forma que o gráfico por si só passe a sua informação e quem estiver vendo o gráfico possa receber a mensagem claramente.
#
# Não querendo entrar muito em detalhes, mas o `seaborn` devolve dois tipos de objetos de Python, os `FacetGrid` e `AxesSubplot`, cada um tem suas peculiaridades e o importante é que `catplot` e `relplot` devolvem `FacetGrid`, que suportam múltiplos gráficos em uma única imagem, enquanto o `AxesSubplot` suporta apenas 1 gráfico.
#
# Como vamos trabalhar com `FacetGrid` é mais fácil usar uma variável para fazer as mudanças de título e legendas

# %%
sns.set_palette('bright')

g = sns.catplot(x='Age', y='Fare', data=titanic, kind='box', sym='', col='Survived')

#Ajusta o título da figura como um todo e y controla a altura desse título central
g.fig.suptitle('Comparação entre Sobreviventes do Titanic', y=1.05)


#Infelizmente não achei um modo direto de alterar os títulos dos subgráficos a não ser assim :/
axes = g.axes.flatten() #aqui você está quebrando seu gráfico em cada um dos seus subplots
axes[0].set_title("Não Sobreviveu")
axes[1].set_title("Sobreviveu")

'''
#Ou ainda alterar esses valores no seu próprio DataFrame já que é uma variável categórica, antes de plottar
mapa = {0: 'Não Sobreviveu',
        1: 'Sobreviveu',
}

titanic['Survived'].replace(mapa, inplace=True)
'''
#Ajusta as legendas em X e em Y
g.set(xlabel='Idade',
      ylabel='Tarifa')

#Para rotacionar as legendas
g.set_xticklabels(rotation=30)

plt.show()

# %% [markdown]
# Vale aqui uma observação para o caso do seu gráfico ser um `AxesSubplot`, para alterar o título da imagem você usa `g.set_title()` que recebe uma string e também pode receber um parâmetro `y`; para alterar as rotações das legendas é possível usar `plt.xticks(rotation=)`

# %% [markdown]
# <h1><li> Exercício </li></h1>
#
# ---
#
# <img src='https://drive.google.com/uc?id=1O5NN8qsyyi15BizOP0pcm9zsHU2t0Joz' width=500>

# %% [markdown]
# Bom, agora é legal colocar um pouco a mão na massa igual a gente fez no meio do Worshop, vou passar um exercício um pouco mais cabuloso para você fazer com um dataset da sua preferência, vou deixar aqui algumas referências de dados que são visualmente interessantes.
#
# *   [Student Performance](https://archive.ics.uci.edu/ml/datasets/Student+Performance)
# *   [Echocardiogram](https://archive.ics.uci.edu/ml/datasets/Echocardiogram)
# *	[University](https://archive.ics.uci.edu/ml/datasets/University)
# *   [Horse Colic](https://archive.ics.uci.edu/ml/datasets/Horse+Colic)
# *   [Contraceptive Method Choice](https://archive.ics.uci.edu/ml/datasets/Contraceptive+Method+Choice)
# *   [Auto MPG](https://archive.ics.uci.edu/ml/datasets/Auto+MPG)
# *    [Abalone](https://archive.ics.uci.edu/ml/datasets/Abalone)
# *    [Iris](https://archive.ics.uci.edu/ml/datasets/Iris)
#
# Esses dataset eu escolhi, pois eles apresentam um balanço legal entre dados numéricos e categóricos e também tem uma documentação bem legal, então as colunas podem ser entendidas com facilidade sobre o que significa cada uma das colunas.
#
# Então bora lá:
#
# a) Importe as bibliotecas `pandas`, `matplotlib` e `seaborn` com os seus devidos apelidos.
#
# b) Depois de ter escolhido o conjunto de dados que mais te interessa, carregue eles nesse notebook e leia eles usando `pandas` e use algumas funções descritivas para das uma olhada geral.
#
# c) Pense em algumas questões que fazem sentido, como sugestão faça 3 perguntas.
# Ex.: Para o Iris, será que o tamanho da sépala se relaciona com o tipo de flor ?
#
# d) Use os plots que você aprendeu hoje como `scatter`, `line`, `box`, `bar` e `count` para tentar achar uma justificativa para suas questões, ver se aquilo que você pensou faz ou não sentido olhando para os dados.
#
# e) Use as ferramentas de personalização para comparar diferentes classes do seu problema e ver como uma determinada feature influencia ela.
#
# E não se esqueça de tentar usar as personalizações para passar a melhor mensagem sobre o que você descobriu com os seus dados.

# %%
# Neste gabarito estarei fazendo de uma forma bem simples uma abordagem para o IRIS dataset
#A)====================================================================================================

import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
#B)====================================================================================================

df = pd.read_csv('Iris.csv')
df.drop('Id', axis=1, inplace=True) #Tira coluna de Id

df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
#C)====================================================================================================

#Será que o comprimento e largura da sépala se relaciona com o tipo de flor ?
#Será que a comprimento e largura da pétala se relaciona com o tipo de flor ?

# %%
#D.1)====================================================================================================

sns.set_style('darkgrid')
sns.set_palette('bright')

g = sns.relplot(x='SepalLengthCm', y='SepalWidthCm', data=df, hue='Species')
g.fig.suptitle('Comparação entre comprimento e largura das Sépalas', y=1.03)
g.set(xlabel='Comprimento',
      ylabel='Largura')

#Muda a legenda
g._legend.set_title("Espécies")
rotulos = ['Setosa', 'Versicolor', 'Virgnica']
for t, l in zip(g._legend.texts, rotulos): t.set_text(l)

# %%
#D.2)====================================================================================================

g = sns.relplot(x='PetalLengthCm', y='PetalWidthCm', data=df, hue='Species')
g.fig.suptitle('Comparação entre comprimento e largura das Pétalas', y=1.03)
g.set(xlabel='Comprimento',
      ylabel='Largura')

#Muda a legenda
g._legend.set_title("Espécies")
rotulos = ['Setosa', 'Versicolor', 'Virgnica']
for t, l in zip(g._legend.texts, rotulos): t.set_text(l)

# %%
#E)====================================================================================================

'''
Como podemos ver os tamanhos de Comprimento e Largura de Sépalas e Pétalas
podem ser uma ferramenta importante para se diferenciar os tipos de flores
sendo que no caso das Pétalas esses valores são um pouco mais decisivos
'''
# Out:
# '\nComo podemos ver os tamanhos de Comprimento e Largura de Sépalas e Pétalas\npodem ser uma ferramenta importante para se diferenciar os tipos de flores\nsendo que no caso das Pétalas esses valores são um pouco mais decisivos\n'

# %% [markdown]
# <h1><li> Considerações finais </li></h1>
#
# ---
#
# <img src='https://drive.google.com/uc?id=1cU7cfekBk5gpC_HQsldQUxSbT_EyyN9J' width=500>
#
# Agradeço a todos que ouviram eu falando até agora e, nessa parte dedico a deixar algumas dicas adicionais de como você pode aprender mais coisas interessantes sobre visualização de dados e inclusive coisas ainda mais legais que dá para você fazer com essa informação como inteligência artificial e machine learning.
#
# *   [Kaggle](https://www.kaggle.com/): Um ótimo local para achar datasets, entrar em competições e ver como as pessoas estão fazendo machine learning
# *   [Datacamp](https://www.datacamp.com/home): Maravilhoso para aprender o básico, a plataforma é muito lindinha e tem tanto vídeos explicativos como exercícios sobre o assunto, é grátis por 6 meses para alunos USP vinculando com uma conta do GitHub Student
# *   [UCI Repository](https://archive.ics.uci.edu/ml/index.php): É um site que tem como o foco guardar repositórios de datasets e é bem legal, muitos deles tem uma documentação boa e acesso fácil (embora o site seja meio feio)
# *   [Turing Talks](https://medium.com/turing-talks): Plataforma do Medium do Turing para divulgar textos a respeito de IA, que abrangem desde os básicos até modelos cabulosos e o melhor de tudo --> É EM PORTUGUÊS
# *   [Towards Data Science](https://towardsdatascience.com/): Plataforma com vários textos também desde o mais básico de machine learning até as coisas mais cabulosas.
#
# Sempre bom também deixar de recomendação as documentações das bibliotecas que usamos e inclusive de algumas outras que podem ser até mais fáceis de usar dependendo do que você quer fazer:
#
# *   [pandas](https://pandas.pydata.org/docs/)
# *   [matplotlib](https://matplotlib.org/3.3.2/contents.html)
# *   [seaborn](https://seaborn.pydata.org/index.html)
# *   [plotly](https://plotly.com/python/)
# *   [ggplot](https://yhat.github.io/ggpy/)
#
# Fico também a disposição para quem quiser me chamar para tirar dúvidas sobre os exercícios ou só quiser bater um papo sobre qualquer coisa mesmo hahaha.
#
#
# <img height="15" width="15" src="https://simpleicons.org/icons/github.svg"/> [Github](https://github.com/EnzoBustos)
#
# <img height="15" width="15" src="https://simpleicons.org/icons/linkedin.svg"/> [Linkedin](https://www.linkedin.com/in/enzo-bustos-029523ab/)
#
# <img height="15" width="15" src="https://simpleicons.org/icons/whatsapp.svg"/> [Whatsapp](https://wa.me/5511948189033)
#
# <img height="15" width="15" src="https://simpleicons.org/icons/facebook.svg"/> [Facebook](https://www.facebook.com/EnzoBustosSilva/)
#
# <img height="15" width="15" src="https://simpleicons.org/icons/instagram.svg"/> [Instagram](https://www.linkedin.com/in/enzo-bustos-029523ab/)
#
#
# E também deixo aqui disponível um Cheat Sheet de `seaborn`, que é como se fosse um resumão de tudo:
#
# <img src='https://drive.google.com/uc?id=1VaNyWQ-TDka28VMHbxi3DPHQ1H3ki95M'>
